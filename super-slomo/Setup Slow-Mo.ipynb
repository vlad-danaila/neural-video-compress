# %%
#!apt install git-all
# !apt -y install git
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   git-man libcurl3-gnutls liberror-perl
# Suggested packages:
#   gettext-base git-daemon-run | git-daemon-sysvinit git-doc git-el git-email
#   git-gui gitk gitweb git-cvs git-mediawiki git-svn
# The following NEW packages will be installed:
#   git git-man libcurl3-gnutls liberror-perl
# 0 upgraded, 4 newly installed, 0 to remove and 25 not upgraded.
# Need to get 4950 kB of archives.
# After this operation, 34.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcurl3-gnutls amd64 7.58.0-2ubuntu3.8 [213 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 liberror-perl all 0.17025-1 [22.8 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 git-man all 1:2.17.1-1ubuntu0.5 [803 kB]
# ...

# %%
# !apt-get install wget
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   wget
# 0 upgraded, 1 newly installed, 0 to remove and 25 not upgraded.
# Need to get 316 kB of archives.
# After this operation, 954 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 wget amd64 1.19.4-1ubuntu2.2 [316 kB]
# Fetched 316 kB in 0s (714 kB/s)
# debconf: delaying package configuration, since apt-utils is not installed
# Selecting previously unselected package wget.
# (Reading database ... 17805 files and directories currently installed.)
# Preparing to unpack .../wget_1.19.4-1ubuntu2.2_amd64.deb ...
# Unpacking wget (1.19.4-1ubuntu2.2) ...
# Setting up wget (1.19.4-1ubuntu2.2) ...

# %%
# !wget 'http://www.cs.ubc.ca/labs/imager/tr/2017/DeepVideoDeblurring/DeepVideoDeblurring_Dataset_Original_High_FPS_Videos.zip'
# Out:
# --2020-03-15 17:41:17--  http://www.cs.ubc.ca/labs/imager/tr/2017/DeepVideoDeblurring/DeepVideoDeblurring_Dataset_Original_High_FPS_Videos.zip
# Resolving www.cs.ubc.ca (www.cs.ubc.ca)... 142.103.6.5
# Connecting to www.cs.ubc.ca (www.cs.ubc.ca)|142.103.6.5|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2995547015 (2.8G) [application/zip]
# Saving to: ‘DeepVideoDeblurring_Dataset_Original_High_FPS_Videos.zip’
#
# DeepVideoDeblurring 100%[===================>]   2.79G  8.43MB/s    in 5m 37s
#
# 2020-03-15 17:46:58 (8.47 MB/s) - ‘DeepVideoDeblurring_Dataset_Original_High_FPS_Videos.zip’ saved [2995547015/2995547015]

# %%
# !unzip "DeepVideoDeblurring_Dataset_Original_High_FPS_Videos.zip" -d "dataset"
# Out:
# Archive:  DeepVideoDeblurring_Dataset_Original_High_FPS_Videos.zip
#    creating: dataset/original_high_fps_videos/
#   inflating: dataset/original_high_fps_videos/.DS_Store
#    creating: dataset/__MACOSX/
#    creating: dataset/__MACOSX/original_high_fps_videos/
#   inflating: dataset/__MACOSX/original_high_fps_videos/._.DS_Store
#   inflating: dataset/original_high_fps_videos/720p_240fps_1.mov
#   inflating: dataset/original_high_fps_videos/720p_240fps_2.mov
#   inflating: dataset/original_high_fps_videos/720p_240fps_3.mov
#   inflating: dataset/original_high_fps_videos/720p_240fps_4.mov
#   inflating: dataset/original_high_fps_videos/720p_240fps_5.mov
#   inflating: dataset/original_high_fps_videos/720p_240fps_6.mov
#   inflating: dataset/original_high_fps_videos/GOPR9633.mp4
#   inflating: dataset/original_high_fps_videos/GOPR9634.mp4
#   inflating: dataset/original_high_fps_videos/GOPR9635.mp4
#   inflating: dataset/original_high_fps_videos/GOPR9636.mp4
# ...

# %%
# !apt-get install -y ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   fontconfig fontconfig-config fonts-dejavu-core i965-va-driver libaacs0
#   libasound2 libasound2-data libass9 libasyncns0 libavc1394-0 libavcodec57
#   libavdevice57 libavfilter6 libavformat57 libavresample3 libavutil55
#   libbdplus0 libbluray2 libbs2b0 libcaca0 libcairo2 libcdio-cdda2
#   libcdio-paranoia2 libcdio17 libchromaprint1 libcroco3 libcrystalhd3
#   libdatrie1 libdc1394-22 libdrm-amdgpu1 libdrm-common libdrm-intel1
#   libdrm-nouveau2 libdrm-radeon1 libdrm2 libegl-mesa0 libegl1 libelf1
#   libfftw3-double3 libflac8 libflite1 libfontconfig1 libfribidi0 libgbm1
#   libgdk-pixbuf2.0-0 libgdk-pixbuf2.0-bin libgdk-pixbuf2.0-common libgl1
#   libgl1-mesa-dri libglapi-mesa libglvnd0 libglx-mesa0 libglx0 libgme0
#   libgraphite2-3 libgsm1 libharfbuzz0b libicu60 libiec61883-0 libjack-jackd2-0
# ...

# %%
# !git clone https://github.com/avinashpaliwal/Super-SloMo.git
# Out:
# Cloning into 'Super-SloMo'...
# remote: Enumerating objects: 174, done.
# remote: Total 174 (delta 0), reused 0 (delta 0), pack-reused 174
# Receiving objects: 100% (174/174), 26.88 MiB | 3.77 MiB/s, done.
# Resolving deltas: 100% (93/93), done.

# %%
# !pip3 install tqdm numpy torch torchvision tensorflow tensorboardX matplotlib
# Out:
# ...
#   Using cached tensorflow-2.1.0-cp36-cp36m-manylinux2010_x86_64.whl (421.8 MB)
# ...
#   Using cached tensorboardX-2.0-py2.py3-none-any.whl (195 kB)
# ...
#   Using cached matplotlib-3.2.0-cp36-cp36m-manylinux1_x86_64.whl (12.4 MB)
# ...
#   Using cached kiwisolver-1.1.0-cp36-cp36m-manylinux1_x86_64.whl (90 kB)
# ...
#   Using cached pyparsing-2.4.6-py2.py3-none-any.whl (67 kB)
# ...
#   Using cached cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# ...

# %%
# !df -h
# Out:
# Filesystem      Size  Used Avail Use% Mounted on
# overlay          14G  9.7G  4.4G  70% /
# tmpfs            64M     0   64M   0% /dev
# tmpfs            63G     0   63G   0% /sys/fs/cgroup
# shm             8.0G     0  8.0G   0% /dev/shm
# /dev/sda4       908G  217G  692G  24% /etc/hosts
# tmpfs            63G   12K   63G   1% /proc/driver/nvidia
# /dev/sda2        15G   13G  2.0G  86% /usr/bin/nvidia-smi
# tmpfs            13G  107M   13G   1% /run/nvidia-persistenced/socket
# udev             63G     0   63G   0% /dev/nvidia4
# tmpfs            63G     0   63G   0% /proc/asound
# tmpfs            63G     0   63G   0% /proc/acpi
# tmpfs            63G     0   63G   0% /proc/scsi
# tmpfs            63G     0   63G   0% /sys/firmware

# %%
# !python Super-SloMo/data/create_dataset.py --ffmpeg_dir '' --videos_folder dataset/original_high_fps_videos --dataset_folder dataset/processed --dataset Super-SloMo/data/adobe240fps
# Out:
# ffmpeg version 3.4.6-0ubuntu0.18.04.1 Copyright (c) 2000-2019 the FFmpeg developers
#   built with gcc 7 (Ubuntu 7.3.0-16ubuntu3)
# ...
